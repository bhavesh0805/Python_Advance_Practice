# %% [markdown]
# # Part A: Basic Module Usage (Level 1)

# %%
#1.	Math Module: Use the built-in math module to find the square root of 625 and the value of $pi$.
import math as m
square_root = m.sqrt(625)
pi= m.pi

# %%
square_root
# Out:
# 25.0

# %%
pi
# Out:
# 3.141592653589793

# %%
# 2.Custom Module: Create a file calculator.py with an add() function. Import it into a new file and use it.
import calculator

# %%
calculator.add(3,4)
# Out:
# 7

# %%
#3.	Alias Practice: Import the platform module as plt and print your operating system name.
import platform as plt
print(plt.system())
# Out:
# Windows

# %%
#4.	Specific Import: Use from random import randint to generate a random number between 1 and 10.
from random import randint
print(randint(1,10))
# Out:
# 5

# %%
#5.	Directory Listing: Use the os module to print all files in your current folder.
import os
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'bio.txt', 'calculator.py', 'cleaned.txt', 'data.csv', 'fil4.txt', 'file1.txt', 'file2.txt', 'file3.txt', 'file4.txt', 'File_Handling.ipynb', 'geo.txt', 'guests.txt', 'hello.txt', 'merged.txt', 'Modules and Packages.ipynb', 'New Text Document.txt', 'OOP1.ipynb', 'OOP2.ipynb', '__pycache__']

# %% [markdown]
# # Part B: Logic for NLP/Data Science (Level 2)

# %%
# 6.Time Logger: Import the datetime module and create a function that returns the current time formatted for a log file.
import datetime

# %%
def cur_time():
    now = datetime.datetime.now()
    print(now)

# %%
cur_time()
# Out:
# 2026-04-16 19:13:10.492595

# %%
#7.	Data Simulation: Use the random module to pick a random "sentiment" (Positive, Negative, Neutral) from a list
import random
sentiment = ['Positive', 'Negative', 'Neutral']
random.choice(sentiment)
# Out:
# 'Positive'

# %%
#8.	System Paths: Use os.path to check if a specific data file exists before trying to open it.
import os
os.path.exists('cleaned.txt')
# Out:
# True

# %%
#9.	String Constants: Import the string module and print all available punctuation marks (essential for cleaning NLP text).
import string
print(string.punctuation)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
#10.JSON Handling: Use the json module to convert a Python dictionary into a JSON string.
import json
dic = {'a' :'Hello' , 'b' : 'World', 'c': 'How are you'}

# %%
json.dumps(dic)
# Out:
# '{"a": "Hello", "b": "World", "c": "How are you"}'

# %% [markdown]
# # Part C: Advanced Organization (Level 3)

# %%
#11.The dir() Function: Use dir() on the math module to see every function available inside it.
import math

# %%
print(dir(math))
# Out:
# ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'cbrt', 'ceil', 'comb', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'e', 'erf', 'erfc', 'exp', 'exp2', 'expm1', 'fabs', 'factorial', 'floor', 'fma', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'lcm', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'nextafter', 'perm', 'pi', 'pow', 'prod', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'sumprod', 'tan', 'tanh', 'tau', 'trunc', 'ulp']

# %%
#12.Folder as Package: Create a folder named mymodules. Inside it, put an empty __init__.py and a logic.py. Try importing from this folder

# %%
from mymodules import empty__init__

# %%
from mymodules import logic

# %%
#13.Global vs Local: Import a variable from a module, change it in your main script, and check if it changed in the original module.
from calculator import add

# %%
def add(a,b):
    result = a*b
    print (result)

# %% [raw]
# --->Changing it locally does not change the original file's code.

# %%
#14.Reloading: Research the importlib.reload() function. Why would you use this during active development?
import importlib

# %%
importlib.reload(math)
# Out:
# <module 'math' (built-in)>

# %% [raw]
# --->Used to update a module in an active session without restarting.

# %%
#15.Module Constants: Define a module config.py that holds your API keys or Database URLs and import them into your main app.
import config

# %%
print(config.API_KEY)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 print(config.API_KEY)
#
# AttributeError: module 'config' has no attribute 'API_KEY'

# %% [markdown]
# # Part D: Expert "Top 1%" Challenges (Level 4)

# %%
#16.Environment Variables: Use the os module to retrieve an environment variable (crucial for security).
import os

# %%
os.environ
# Out:
# environ{'ALLUSERSPROFILE': 'C:\\ProgramData',
#         'APPDATA': 'C:\\Users\\bhave\\AppData\\Roaming',
#         'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files',
#         'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files',
#         'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files',
#         'COMPUTERNAME': 'BHAVESH_PC',
#         'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe',
#         'CONDA_PREFIX': 'C:\\Users\\bhave\\anaconda3',
#         'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData',
#         'EFC_10604_1592913036': '1',
#         'HOMEDRIVE': 'C:',
#         'HOMEPATH': '\\Users\\bhave',
#         'IPY_INTERRUPT_EVENT': '1780',
#         'JPY_INTERRUPT_EVENT': '1780',
#         'JPY_PARENT_PID': '2896',
#         'JPY_SESSION_NAME': 'C:\\Users\\bhave\\Downloads\\705\\Advance_python_practice\\Modules and Packages.ipynb',
#         'LOCALAPPDATA': 'C:\\Users\\bhave\\AppData\\Local',
#         'LOGONSERVER': '\\\\BHAVESH_PC',
# ...

# %%
#17.Sys Path: Import the sys module and print sys.path. Explain how Python knows where to look for modules
import sys
sys.path
# Out:
# ['C:\\Users\\bhave\\anaconda3\\python313.zip',
#  'C:\\Users\\bhave\\anaconda3\\DLLs',
#  'C:\\Users\\bhave\\anaconda3\\Lib',
#  'C:\\Users\\bhave\\anaconda3',
#  '',
#  'C:\\Users\\bhave\\anaconda3\\Lib\\site-packages',
#  'C:\\Users\\bhave\\anaconda3\\Lib\\site-packages\\win32',
#  'C:\\Users\\bhave\\anaconda3\\Lib\\site-packages\\win32\\lib',
#  'C:\\Users\\bhave\\anaconda3\\Lib\\site-packages\\Pythonwin']

# %%
#18.Custom NLP Module: Create a module text_utils.py with functions for remove_spaces() and word_count(). Use it to process a sentence.
import text_utils
